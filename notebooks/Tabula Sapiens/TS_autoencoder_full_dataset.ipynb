# %%
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.optim as optim
import anndata as ad

# %%
path = '../../data/TS.h5ad'
ts_ann_data = ad.read_h5ad(path)

# %%
ts_df = ts_ann_data.to_df()
# Drop zero columns
ts_df = ts_df.loc[:, (ts_df != 0).any(axis=0)]
ts_df
# Out:
# ensemblid                                           ENSG00000227232  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000243485  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000186092  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000238009  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000239945  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000233750  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000268903  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000269981  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000241860  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000222623  ...  \
# cell_id                                                              ...
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0  ...
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0  ...
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0  ...
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0  ...
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0  ...
# ...                                                             ...  ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0  ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0  ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0  ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0  ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0  ...
#
# ensemblid                                           ENSG00000212907  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                 1.492649
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                 1.903640
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                 0.971113
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                 1.249330
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                 1.378214
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.193500
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.111410
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         1.318307
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         2.771708
#
# ensemblid                                           ENSG00000198886  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                 3.470269
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                 3.251729
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                 3.264437
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                 2.353345
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                 3.787100
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         1.909840
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         1.511308
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.517196
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         1.186609
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         2.671342
#
# ensemblid                                           ENSG00000210176  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000210191  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000198786  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                 2.023797
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                 2.110188
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                 1.785083
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                 0.793493
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                 2.702034
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.093893
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         1.353644
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.966540
#
# ensemblid                                           ENSG00000198695  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                 2.026197
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                 1.450374
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                 0.000000
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         1.092484
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         1.499545
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.322826
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
#
# ensemblid                                           ENSG00000210194  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                 0.000000
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.009120
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.032304
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
#
# ensemblid                                           ENSG00000198727  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                 3.764314
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                 3.375192
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                 3.837567
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                 3.151370
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                 3.961854
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.030039
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         2.161131
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         2.462929
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         3.788884
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         3.022644
#
# ensemblid                                           ENSG00000210195  \
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                      0.0
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                      0.0
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...              0.0
#
# ensemblid                                           ENSG00000210196
# cell_id
# AAACCCAAGAGCAAGA_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGATGGCGT_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGGGTTAAT_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGTATGCAA_TSP12_Heart_Atria_10X_1_1                 0.000000
# AAACCCAAGTCGTTAC_TSP12_Heart_Atria_10X_1_1                 0.574412
# ...                                                             ...
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.110261
# TSP12_Heart_ventricle_SS2_B133716_B134037_LIve_...         0.000000
#
# [11505 rows x 41159 columns]

# %%
train_df, test_df = train_test_split(ts_df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.1, random_state=42)

# %%
print(len(train_df))
print(len(val_df))
print(len(test_df))
# Out:
# 8283
# 921
# 2301

# %%
class TSDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):

        features = torch.tensor(self.df.iloc[idx], dtype=torch.float32)

        if self.transform:
            features = self.transform(features)

        return features, features # for Autoencoder

# %%
# Set hyperparameters
input_size = len(ts_df.columns)
encoding_size = 5000
learning_rate = 1e-4
epochs = 50
batch_size = 265

# %%
train_dataset = TSDataset(train_df)
val_dataset = TSDataset(val_df)
test_dataset = TSDataset(test_df)

# Define DataLoader for each set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Define Autoencoder model
class Autoencoder(nn.Module):
    def __init__(self, input_size, encoding_size):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Linear(input_size, encoding_size)
        self.decoder = nn.Linear(encoding_size, input_size)
        self.nonlin = nn.ReLU()

    def forward(self, x):
        x = self.encoder(x)
        x = self.nonlin(x)
        x = self.decoder(x)
        x = self.nonlin(x)
        return x

# %%
# Initialize model, loss function, and optimizer
model = Autoencoder(input_size, encoding_size)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training loop
for epoch in range(epochs):
    # Train step
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
    print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {loss.item():.4f}')

    # Val step
    with torch.no_grad():
        for inputs, targets in train_loader:
            model.eval()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
        print(f'Validation Loss: {loss.item():.4f}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3789'>3790</a> try:
# -> <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3790'>3791</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3791'>3792</a> except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1351
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 9
#       6 # Training loop
#       7 for epoch in range(epochs):
#       8     # Train step
# ----> 9     for inputs, targets in train_loader:
#      10         optimizer.zero_grad()
#      11         outputs = model(inputs)
#
# File ~/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=626'>627</a> if self._sampler_iter is None:
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=627'>628</a>     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=628'>629</a>     self._reset()  # type: ignore[call-arg]
# --> <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=629'>630</a> data = self._next_data()
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=630'>631</a> self._num_yielded += 1
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=631'>632</a> if self._dataset_kind == _DatasetKind.Iterable and \
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=632'>633</a>         self._IterableDataset_len_called is not None and \
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=633'>634</a>         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=671'>672</a> def _next_data(self):
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=672'>673</a>     index = self._next_index()  # may raise StopIteration
# --> <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=673'>674</a>     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=674'>675</a>     if self._pin_memory:
#     <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/dataloader.py?line=675'>676</a>         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = self.dataset.__getitems__(possibly_batched_index)
#      <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
# ---> <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=51'>52</a> else:
#      <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=52'>53</a>     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = self.dataset.__getitems__(possibly_batched_index)
#      <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
# ---> <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=51'>52</a> else:
#      <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py?line=52'>53</a>     data = self.dataset[possibly_batched_index]
#
# Cell In[6], line 11, in TSDataset.__getitem__(self, idx)
#       9 def __getitem__(self, idx):
# ---> 11     features = torch.tensor(self.df[idx], dtype=torch.float32)
#      13     if self.transform:
#      14         features = self.transform(features)
#
# File ~/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/frame.py?line=3890'>3891</a> if self.columns.nlevels > 1:
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/frame.py?line=3891'>3892</a>     return self._getitem_multilevel(key)
# -> <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/frame.py?line=3892'>3893</a> indexer = self.columns.get_loc(key)
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/frame.py?line=3893'>3894</a> if is_integer(indexer):
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/frame.py?line=3894'>3895</a>     indexer = [indexer]
#
# File ~/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3792'>3793</a>     if isinstance(casted_key, slice) or (
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3793'>3794</a>         isinstance(casted_key, abc.Iterable)
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3794'>3795</a>         and any(isinstance(x, slice) for x in casted_key)
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3795'>3796</a>     ):
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3796'>3797</a>         raise InvalidIndexError(key)
# -> <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3797'>3798</a>     raise KeyError(key) from err
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3798'>3799</a> except TypeError:
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3799'>3800</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3800'>3801</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3801'>3802</a>     #  the TypeError.
#    <a href='file:///Users/marco.basmaji/anaconda3/envs/sysgen/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3802'>3803</a>     self._check_indexing_error(key)
#
# KeyError: 1351
